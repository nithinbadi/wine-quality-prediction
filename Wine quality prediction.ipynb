# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Acknowledgements
# <p>This dataset is also available from the UCI machine learning repository,<a href=' https://archive.ics.uci.edu/ml/datasets/wine+quality'>https://archive.ics.uci.edu/ml/datasets/wine+quality</a> , I just borrowed it from kaggle for convenience. <i>I am not the owner of this dataset.</i></p>

# %%
wine_df = pd.read_csv('winequality-red.csv')
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine_df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %% [markdown]
# quality > 6.5 => "good"

# %%
wine_df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
print(f'Shape of the dataset is {wine_df.shape[0]} rows and {wine_df.shape[1]} columns')
# Out:
# Shape of the dataset is 1599 rows and 12 columns

# %%
print(wine_df.columns)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
plt.figure(figsize=(10,7))
sns.heatmap(wine_df.corr(),annot=True,cmap='crest',fmt='.2f');

# %% [markdown]
# <li>Density has a strong correlation of 0.67 with fixed acidity</li>
# <li>pH value has a negative correlation of 0.68 with fixed acidity</li>
# <li>citric acid has a strong correlation of 0.67 with fixed acidity</li>
# <li>alcohol has the strongest correlation with quality which is 0.48</li>

# %%
plt.bar(wine_df.quality.unique(),height=wine_df.quality.value_counts());
plt.title('Wine quality bar plot');
plt.xlabel('Quality');
plt.ylabel('Count');

# %%
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#labelling the data into good or bad using pd.cut operayion
bins=(2,6.5,9)
groups = ['bad','good']
wine_df['quality'] = pd.cut(wine_df['quality'],bins=bins,labels=groups)

# %%
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4     bad
# 1      9.8     bad
# 2      9.8     bad
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_quality = LabelEncoder()
wine_df['quality'] = label_quality.fit_transform(wine_df['quality'])
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        0
# 1      9.8        0
# 2      9.8        0
# ...

# %%
wine_df.quality.value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %%
X = wine_df.drop('quality',axis=1)
y = wine_df.quality

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=42)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((1359, 11), (240, 11), (1359,), (240,))

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rfc.predict(X_test)

from sklearn.metrics import classification_report

print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94       217
#            1       0.46      0.74      0.57        23
#
#     accuracy                           0.89       240
#    macro avg       0.71      0.82      0.75       240
# weighted avg       0.92      0.89      0.90       240

# %% [markdown]
# Produced 89% accuracy with the Random Forest Classifier
